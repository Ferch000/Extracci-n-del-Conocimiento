# %% [markdown]
# # Datos Sintéticos
# ## Utilización de la libreria FAKER
# *Autor: Fernando Torres Zonahua*

# %%
import pandas as pd
import numpy as np
import random

# %%
# Importamos la libreria Faker
from faker import Faker

# %%
# Creamos una instancia de Faker
fake = Faker("es_MX")

# %%
# Generamos datos sintéticos o datos falsos
datos = []
for i in range(100):
    datos.append(
        {
            "id_usuario": i +1,
            "nombre" : fake.name(),
            "correo" : fake.email(),
            "edad" : random.randint(18,65),
            "seguidores" : random.randint(50,5000),
            "plataforma" : random.choice(["TikTok", "Instagram", "Youtube"])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                      nombre                      correo  edad  \
# 0            1           Ing. Miguel Frías     jaimessalma@example.net    27
# 1            2     Srita. Jaqueline Guerra    gloriagalvan@example.com    58
# 2            3          Rosa Ofelia Jáquez         csolano@example.net    47
# 3            4       Violeta Amelia Corona   peralesanabel@example.org    57
# 4            5  Cristina Anguiano Coronado    jaimebriones@example.org    39
# ..         ...                         ...                         ...   ...
# 95          96       Cornelio Mota Delgado         dario80@example.org    35
# 96          97              Wilfrido Prado     curielmayte@example.org    47
# 97          98        Lic. Daniela Ornelas  maria-teresa72@example.org    59
# 98          99            Genaro Solorzano        marcos95@example.com    52
# 99         100          Lic. Rafaél Dueñas    griegohomero@example.net    32
#
#     seguidores plataforma
# 0         2757  Instagram
# 1         4415  Instagram
# 2          822     TikTok
# 3         1650  Instagram
# 4         3431  Instagram
# ..         ...        ...
# 95        4801     TikTok
# 96         343    Youtube
# 97        4894    Youtube
# 98        1690    Youtube
# 99          61     TikTok
#
# [100 rows x 6 columns]

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    object
#  2   correo      100 non-null    object
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   42.240000  2501.960000
# std     29.011492   13.338726  1461.855151
# min      1.000000   19.000000    61.000000
# 25%     25.750000   32.000000  1227.250000
# 50%     50.500000   42.000000  2572.000000
# 75%     75.250000   54.000000  3764.500000
# max    100.000000   65.000000  4984.000000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario             nombre                   correo        edad  \
# count   100.000000                100                      100  100.000000
# unique         NaN                100                      100         NaN
# top            NaN  Ing. Miguel Frías  jaimessalma@example.net         NaN
# freq           NaN                  1                        1         NaN
# mean     50.500000                NaN                      NaN   42.240000
# std      29.011492                NaN                      NaN   13.338726
# min       1.000000                NaN                      NaN   19.000000
# 25%      25.750000                NaN                      NaN   32.000000
# 50%      50.500000                NaN                      NaN   42.000000
# 75%      75.250000                NaN                      NaN   54.000000
# max     100.000000                NaN                      NaN   65.000000
#
#          seguidores plataforma
# count    100.000000        100
# unique          NaN          3
# top             NaN    Youtube
# freq            NaN         43
# mean    2501.960000        NaN
# std     1461.855151        NaN
# min       61.000000        NaN
# 25%     1227.250000        NaN
# 50%     2572.000000        NaN
# 75%     3764.500000        NaN
# max     4984.000000        NaN

# %%
# Graficar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Graficamos como se generaron las edades
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribución de edades")
plt.show()

# %%
# Graficamos la cantidad de usuarios por plataforma
plt.figure(figsize=(8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("Cantidad de usuarios por plataforma")
plt.show()
